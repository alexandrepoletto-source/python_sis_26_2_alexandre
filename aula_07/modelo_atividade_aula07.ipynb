# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandrepoletto-source/python_sis_26_2_alexandre/blob/alexandre_poletto_alt/aula_07/modelo_atividade_aula07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Atividade Prática 01 Aula 07:
# ## Caça aos Bugs (Traceback)
# Execute os códigos abaixo, um por vez. O programa vai 'quebrar' e exibir um erro no terminal. Sua missão é ler o traceback, descobrir qual é a linha do erro, qual é o tipo do erro e corrigir o código para que ele funcione, adicione um comentário sobre a coreção.

# %%
nome_heroi = "Batman"
print("O herói que vai salvar a cidade é o " + nome_heroi_cidade)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4579/983125055.py in <cell line: 0>()
#       1 nome_heroi = "Batman"
# ----> 2 print("O herói que vai salvar a cidade é o " + nome_heroi_cidade)
#
# NameError: name 'nome_heroi_cidade' is not defined

# %%
nome_heroi = "Batman"
print("O herói que vai salvar a cidade é o " + nome_heroi)
#Neste código a variável do nome do herói é nome_heroi, no primeiro código essa variável é buscada no print de forma errada como "nome_heroi_cidade"
# Out:
# O herói que vai salvar a cidade é o Batman

# %%
idade_pet = 5
mensagem = "A idade do meu cachorro é " + idade_pet + " anos."
print(mensagem)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4579/1236647575.py in <cell line: 0>()
#       1 idade_pet = 5
# ----> 2 mensagem = "A idade do meu cachorro é " + idade_pet + " anos."
#       3 print(mensagem)
#
# TypeError: can only concatenate str (not "int") to str

# %%
idade_pet = 5
mensagem = "A idade do meu cachorro é " + str(idade_pet) + " anos."
print(mensagem)
#Neste código a mensagem apresentava um erro nos tipos de variável, para arrumar
#foi preciso converter a váriavel idade_pet para o tipo str para ser apresentada junto com o resto do texto
# Out:
# A idade do meu cachorro é 5 anos.

# %%
print("Calculadora de Dobro!")
# Simulando alguém que digitou a palavra 'dez' em vez do número 10
numero_digitado = "dez"
dobro = int(numero_digitado) * 2
print("O dobro é:", dobro)

# %%
# Seu código aqui

# %%
cat_attributes = {
    "name": "Zia",
    "age": 1,
    "color": "grey"
}

# Tentando descobrir a raça (breed) da gata
raca_gato = cat_attributes["breed"]
print("A raça da gata é:", raca_gato)

# %%
# Seu código aqui

# %%
some_numbers = [10, 20, 30]

# Tentando acessar o quarto número da lista
quarto_numero = some_numbers[3]
print("O número escolhido foi:", quarto_numero)

# %%
# Seu código aqui

# %%
tesouro_moedas = 100
aventureiros_sobreviventes = 0

print("Calculando a divisão do tesouro...")

moedas_por_pessoa = tesouro_moedas / aventureiros_sobreviventes

print("Cada aventureiro vai receber:", moedas_por_pessoa)

# %%
# Seu código aqui

# %%
print("=== Sistema do Zoológico ===")
# horário, alimento, quantidade
dieta_axolote = ("08:00", "minhocas", 50)

print("O axolote enjoou de minhocas. Vamos alterar a dieta para pizza!")

dieta_axolote[1] = "pizza de calabresa"

print("Nova dieta:", dieta_axolote)

# %%
# Seu código aqui

# %%
def contagem_regressiva(tempo):


    print(f"Faltam {tempo} segundos...")

    # Passo Recursivo: A função chama a si mesma
    contagem_regressiva(tempo - 1)

print("Iniciando contagem para a explosão do Anel...")
contagem_regressiva(3)

# %%
# Seu código aqui

# %% [markdown]
# # Atividade Prática 02 Aula 07 -
# ## Parte 01 - Caça aos Bugs  - Soneca de gato com bugs
# Nós escrevemos um programa para calcular o tempo total que o gato dorme em um dia. Mas algo parece estranho... O total que a nossa função retorna não corresponde ao tempo real que o gato passou tirando sonecas:
# * Mesmo que você identifique o erro neste código logo de cara, pratique usar comandos print, um ponto de interrupção (breakpoint) ou o registro de rastreamento (traceback log) para descobrir o que está errado e com que tipo de bug estamos lidando.
# * Além disso, corrija o problema para que a função retorne o tempo total de soneca correto.

# %%
def nap_time(hours_list):
    total = 0
    counter = 1
    while counter < len(hours_list):
        total += hours_list[counter]
        print(counter)
        counter += 1
    return total
cat_naps = [2, 3, 1.5, 4]
print("Total nap time:", nap_time(cat_naps))
# Out:
# 1
# 2
# 2
# 3
# 3
# 4
# Total nap time: 8.5

# %%
def nap_time(hours_list):
    total = 0
    counter = 0
    while counter < len(hours_list):
        total += hours_list[counter]
        print(counter)
        counter += 1
    return total
cat_naps = [2, 3, 1.5, 4]
print("Total nap time:", nap_time(cat_naps))
#No código apresentado a variável que acumulava as horas de soneca (counter)
#começava a partir de "1 hora", o que causava um erro no resultado
#das horas totais de soneca, para corrigir isso fiz com que o contador de horas
#começasse do zero
# Out:
# 0
# 1
# 2
# 3
# Total nap time: 10.5

# %% [markdown]
# # Atividade Prática 02 Aula 07 -
# ## Parte 02 - Quanto o seu gato mia?
# Imagine que você escreveu este programa para calcular com que frequência o seu gato mia, em média, por hora acordado. Você manteve um registro de quanto ele miou e de quanto ele dormiu a cada dia. Você arredondou os tempos de soneca; afinal, você é um desenvolvedor de software, não um veterinário. Tudo no seu código parece estar perfeitamente bem. Mas adivinha? O programa trava mesmo assim.
# Hora de depurar (debug)!
# Use o traceback, declarações print e/ou pontos de interrupção (breakpoints) para descobrir o que está causando o travamento e com que tipo de bug você está lidando. Pense em uma maneira inteligente de modificar o código para que ele não trave mais:

# %%
def average_meows(logs):
    total_meows_per_hour = 0

    for log in logs:
        nap_hours = 0

        for nap in log["naps"]:
            nap_hours += nap

        awake_hours = 24 - nap_hours
        total_meows_per_hour += log["meows"] / awake_hours

    return total_meows_per_hour / len(logs)

logs = [
    {"day": "Monday", "naps": [1, 2, 5], "meows": 90},
    {"day": "Tuesday", "naps": [4, 3, 2], "meows": 75},
    {"day": "Wednesday", "naps": [8, 6, 9, 1], "meows": 9},
    {"day": "Thursday", "naps": [1, 1, 5, 7], "meows": 38},
    {"day": "Friday", "naps": [3, 3, 2, 8], "meows": 94},
    {"day": "Saturday", "naps": [4, 8, 3], "meows": 64},
    {"day": "Sunday", "naps": [3, 3, 2, 8], "meows": 37}
]

print("Average meows per awake hour:", average_meows(logs))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_4579/2475428855.py in <cell line: 0>()
#      23 ]
#      24
# ---> 25 print("Average meows per awake hour:", average_meows(logs))
#
# /tmp/ipykernel_4579/2475428855.py in average_meows(logs)
#       9
#      10         awake_hours = 24 - nap_hours
# ---> 11         total_meows_per_hour += log["meows"] / awake_hours
#      12
#      13     return total_meows_per_hour / len(logs)
#
# ZeroDivisionError: division by zero

# %%
def average_meows(logs):
    total_meows_per_hour = 0
    print(total_meows_per_hour)

    for log in logs:
        nap_hours = 0

        for nap in log["naps"]:
            nap_hours = nap
        awake_hours = 24 - nap_hours
        total_meows_per_hour += log["meows"] / awake_hours
        print(total_meows_per_hour)

    return total_meows_per_hour / len(logs)

logs = [
    {"day": "Monday", "naps": [1, 2, 5], "meows": 90},
    {"day": "Tuesday", "naps": [4, 3, 2], "meows": 75},
    {"day": "Wednesday", "naps": [8, 6, 9, 1], "meows": 9},
    {"day": "Thursday", "naps": [1, 1, 5, 7], "meows": 38},
    {"day": "Friday", "naps": [3, 3, 2, 8], "meows": 94},
    {"day": "Saturday", "naps": [4, 8, 3], "meows": 64},
    {"day": "Sunday", "naps": [3, 3, 2, 8], "meows": 37}
]
print("Average meows per awake hour:", average_meows(logs))

#Na linha 8 do código a variável nap_hours estava executando uma adição na variável
#que registra as horas de soneca, causando um erro na operação final de média de miados
#por hora acordada, para corrigir isto foi retirado o sinal de adição da variável nap_hours
# Out:
# 0
# 4.7368421052631575
# 8.145933014354068
# 8.537237362180155
# 10.772531479827215
# 16.647531479827215
# 19.695150527446263
# 22.007650527446263
# Average meows per awake hour: 3.143950075349466

# %% [markdown]
# # Atividade Prática 02 Aula 07 -
# ## Parte 03 - Bugs na Trilha
# Você está escrevendo um programa que calcula a distância total de uma trilha. Os dados são flexíveis, e cada segmento da trilha é passado como uma tupla que consiste na distância e na unidade. A função deve imprimir o total de todos esses segmentos. O programa roda sem travar (não quebra), mas algo sobre esse total parece estar errado...
# Use técnicas de depuração (debugging) para descobrir o que há de errado com este código e conserte o bug:

# %%
def total_distance(*segments):
    total = 0
    for length, unit in segments:
        if unit.lower() == "M":
            total += length
        elif unit.lower() == "km":
            total += length * 1000
        elif unit.lower() == "KM":
            total += length * 1000
        else :
            unit.lower() == "m"
            total += length

    print("Total distance:", total, "meters")

total_distance(
    (2.5, "km"),
    (400, "M"),
    (1.0, "km"),
    (800, "m"),
    (1.3, "KM"),
    (900, "m "),
    (1.1, "km")
)
# Out:
# Total distance: 8000.0 meters

# %%
# Seu código aqui

# %% [markdown]
# # Atividade Prática 03 Aula 07 -
# ## Caça aos Bugs e Tratamento de Erros - Ingressos do museu
#
# Você está ajudando um museu local a configurar uma máquina de ingressos. Você escreveu um programa em Python para ela: o visitante digita a sua idade, e a máquina imprime o tipo de ingresso que ele recebe. A lógica é simples:
#
# * Crianças menores de 12 anos têm acesso gratuito;
# * Adolescentes menores de 18 anos recebem um desconto para jovens;
# * Adultos menores de 65 anos pagam o valor integral;
# * Pessoas com 65 anos ou mais recebem um desconto para idosos;
#
# Porém você deve tratar o código para que independente doque o visitante digite o programa não dê erro.
#
# Caso seja uma idade válida o programa deve dar as boas vindas. Caso não deve pedir redigitação.
#
# E independente do usuário digita certo ou errado o sistema deve limpar a tela para aguardar pelo próximo visitante.

# %%
def ticket_type():
    age = input("Enter your age: ")
    if age < 12:
        print("You get in for free. Lucky you!")
    elif age < 18:
        print("You get a youth discount!")
    elif age < 65:
        print("That's a full-price ticket for you.")
    else:
        print("You get a senior discount!")

ticket_type()

# %%
# Seu código aqui
